# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
movies = pd.read_csv("movie_metadata.csv")

# %%
movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
# color                        5024 non-null object
# director_name                4939 non-null object
# num_critic_for_reviews       4993 non-null float64
# duration                     5028 non-null float64
# director_facebook_likes      4939 non-null float64
# actor_3_facebook_likes       5020 non-null float64
# actor_2_name                 5030 non-null object
# actor_1_facebook_likes       5036 non-null float64
# gross                        4159 non-null float64
# genres                       5043 non-null object
# actor_1_name                 5036 non-null object
# movie_title                  5043 non-null object
# num_voted_users              5043 non-null int64
# cast_total_facebook_likes    5043 non-null int64
# actor_3_name                 5020 non-null object
# facenumber_in_poster         5030 non-null float64
# ...

# %% [markdown]
# *** Data preprocessing ***

# %% [markdown]
# #1 Let's remove some useless features.

# %%
sns.lmplot(y='imdb_score',x='movie_facebook_likes',data=movies)

# %%
sns.lmplot(y='imdb_score',x='director_facebook_likes',data=movies)

# %%
sns.lmplot(y='imdb_score',x='cast_total_facebook_likes',data=movies)

# %% [markdown]
# from the above plots, we can say there is no correkation between the movie imdb ratings an facebook likes! So we will create a new dataset dropping the 'facebook' columns

# %%
fbookcols = movies.columns[movies.columns.str.contains('facebook')]
movie_temp = movies.drop(fbookcols,axis=1)
movie_2 = movie_temp.drop('movie_imdb_link',axis=1)

movie_new_dataset = movie_2[movie_2['num_user_for_reviews'] > 100]

# %%
movie_new_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3228 entries, 0 to 5039
# Data columns (total 21 columns):
# color                     3226 non-null object
# director_name             3203 non-null object
# num_critic_for_reviews    3228 non-null float64
# duration                  3228 non-null float64
# actor_2_name              3227 non-null object
# gross                     3027 non-null float64
# genres                    3228 non-null object
# actor_1_name              3228 non-null object
# movie_title               3228 non-null object
# num_voted_users           3228 non-null int64
# actor_3_name              3223 non-null object
# facenumber_in_poster      3222 non-null float64
# plot_keywords             3227 non-null object
# num_user_for_reviews      3228 non-null float64
# language                  3227 non-null object
# country                   3228 non-null object
# content_rating            3219 non-null object
# budget                    3105 non-null float64
# ...

# %% [markdown]
# There are some NaNs let's see how much

# %%
plt.figure(figsize=(13, 40))
plt.rcParams['axes.facecolor'] = 'black'
plt.rc('grid', color='#202020')
(movie_new_dataset.isnull().mean(axis=0)*100).plot.barh(color ="#FF6600")
plt.xlim(xmax=100)
plt.title("Missing values rate",fontsize=18)
plt.xlabel("percentage",fontsize=14)

# %%
movie_new_dataset[movie_new_dataset['country'] == 'Kenya']
# Out:
#                  color director_name  num_critic_for_reviews  duration  \
# 5022   Black and White    Jim Chuchu                     6.0      60.0
#
#       director_facebook_likes  actor_3_facebook_likes   actor_2_name  \
# 5022                      0.0                     4.0  Olwenya Maina
#
#       actor_1_facebook_likes  gross genres         ...           \
# 5022                   147.0    NaN  Drama         ...
#
#      num_user_for_reviews language  country  content_rating   budget  \
# 5022                  1.0  Swahili    Kenya             NaN  15000.0
#
#       title_year actor_2_facebook_likes  imdb_score aspect_ratio  \
# 5022      2014.0                   19.0         7.4          NaN
#
#      movie_facebook_likes
# 5022                   45
#
# [1 rows x 27 columns]

# %%
x = movie_new_dataset['country']
1.0*len(x.unique())/len(x)
x.unique()
# Out:
# array(['USA', 'UK', nan, 'New Zealand', 'Canada', 'Australia', 'Belgium',
#        'Japan', 'Germany', 'China', 'France', 'New Line', 'Mexico',
#        'Spain', 'Hong Kong', 'Czech Republic', 'India', 'Soviet Union',
#        'South Korea', 'Peru', 'Italy', 'Russia', 'Aruba', 'Denmark',
#        'Libya', 'Ireland', 'South Africa', 'Iceland', 'Switzerland',
#        'Romania', 'West Germany', 'Chile', 'Netherlands', 'Hungary',
#        'Panama', 'Greece', 'Sweden', 'Norway', 'Taiwan', 'Official site',
#        'Cambodia', 'Thailand', 'Slovakia', 'Bulgaria', 'Iran', 'Poland',
#        'Georgia', 'Turkey', 'Nigeria', 'Brazil', 'Finland', 'Bahamas',
#        'Argentina', 'Colombia', 'Israel', 'Egypt', 'Kyrgyzstan',
#        'Indonesia', 'Pakistan', 'Slovenia', 'Afghanistan',
#        'Dominican Republic', 'Cameroon', 'United Arab Emirates', 'Kenya',
#        'Philippines'], dtype=object)
